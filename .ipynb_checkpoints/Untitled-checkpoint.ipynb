# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.linear_model import LinearRegression


def calc_fpts(df_proj):


    print("error in calculating?")
    pass_yds_pts = .04
    pass_td_pts = 4
    pass_int_pts = -1

    rush_yds_pts = .1

    rec_att_pts = 0
    rec_yds_pts = .1
    
    rush_red_td_pts = 6

    fumble_lost_pts = -2

    df_proj['fpts'] = df_proj.pass_yds*pass_yds_pts + df_proj.pass_td*pass_td_pts + df_proj.pass_int*pass_int_pts + \
                    df_proj.rec_att*rec_att_pts + df_proj.rec_yds*rec_yds_pts + df_proj.rec_td*rush_red_td_pts +\
                    df_proj.rush_yds*rush_yds_pts + df_proj.rush_td*rush_red_td_pts +\
                    df_proj.fumble_lost*fumble_lost_pts


    return(df_proj)


def clean_fantasy_pull(df_proj):
    


    # Columns to convert to float
    float_columns = ['pass_yds',  'rush_yds', 'rec_yds']

    for col in float_columns:
        df_proj[col] = df_proj[col].str.replace(',', '').astype(float)

    df_proj.fillna(0, inplace=True)
    


    print("error before calc?")



    df_proj = calc_fpts(df_proj).sort_values(by='fpts', ascending = False)
    
    return(df_proj)

# %%
#Read In Data
df_proj = pd.read_csv('Data/fpros_projections.csv')
df_proj_floor = pd.read_csv('Data/fpros_projections_floor.csv')
df_proj_ceil = pd.read_csv('Data/fpros_projections_ceil.csv')

#Data Clean
df_proj = clean_fantasy_pull(df_proj)

df_proj_floor = clean_fantasy_pull(df_proj_floor)
df_proj_floor['player'] = df_proj_floor['player'].str.replace('low', '')
df_proj_floor = df_proj_floor[['player', 'fpts']]
df_proj_floor.rename(columns={"fpts": "fpts_floor"}, inplace=True)

df_proj_ceil = clean_fantasy_pull(df_proj_ceil)
df_proj_ceil['player'] = df_proj_ceil['player'].str.replace('high', '')
df_proj_ceil = df_proj_ceil[['player', 'fpts']]
df_proj_ceil.rename(columns={"fpts": "fpts_ceil"}, inplace=True)
# Out:
# error before calc?
# error in calculating?
# error before calc?
# error in calculating?
# error before calc?
# error in calculating?

# %%
#Combine Data
df_proj = pd.merge(df_proj, df_proj_ceil, how = 'left', on = 'player' )
df_proj = pd.merge(df_proj, df_proj_floor, how = 'left', on = 'player' )


df_proj = df_proj[['player', 'team', 'position', 'fpts', 'fpts_ceil', 'fpts_floor']]

df_proj = df_proj.sort_values(by=['position', 'fpts'], ascending=[True, False])

# Assign ranks within each position group & add fields

df_proj['voltailty'] =  df_proj.fpts_ceil - df_proj.fpts_floor
df_proj['fpts_upside'] =  df_proj.fpts_ceil - df_proj.fpts
df_proj['fpts_downside'] =  df_proj.fpts_floor - df_proj.fpts

df_proj['pos_rank'] = df_proj.groupby('position').cumcount() + 1

# %%
# Create a linear regression model
model = LinearRegression()

df_proj.fillna(0, inplace=True)

# Fit the model
X = df_proj[['fpts']]
y = df_proj['fpts_upside']
model.fit(X, y)

df_proj['fpts_upside_error'] = model.predict(X) - df_proj['fpts_upside']

# %%
df_proj
# Out:
#                  player team position     fpts  fpts_ceil  fpts_floor  \
# 0    Patrick Mahomes II   KC       QB  384.136    420.674     338.588
# 1            Josh Allen  BUF       QB  380.346    420.004     342.844
# 2           Jalen Hurts  PHI       QB  376.470    449.660     305.198
# 3         Lamar Jackson  BAL       QB  351.434    399.730     275.120
# 4            Joe Burrow  CIN       QB  345.974    384.380     300.700
# ..                  ...  ...      ...      ...        ...         ...
# 540        Kirk Merritt   NO       WR    1.580     13.080       1.580
# 541        Kirk Merritt   NO       WR    1.580      1.580      13.080
# 542        Kirk Merritt   NO       WR    1.580      1.580       1.580
# 543    Laquon Treadwell  BAL       WR    0.950      0.950       0.950
# 545       Antoine Green  DET       WR    0.770      0.770       0.770
#
#      voltailty  fpts_upside  fpts_downside  pos_rank  fpts_upside_error
# 0       82.086       36.538        -45.548         1          67.016442
# 1       77.160       39.658        -37.502         2          66.460636
# 2      144.462       73.190        -71.272         3          65.892218
# 3      124.610       48.296        -76.314         4          62.220674
# 4       83.680       38.406        -45.274         5          61.419962
# ..         ...          ...            ...       ...                ...
# 540     11.500       11.500          0.000       192          10.914380
# 541    -11.500        0.000         11.500       193          10.914380
# 542      0.000        0.000          0.000       194          10.914380
# 543      0.000        0.000          0.000       195          10.821990
# 545      0.000        0.000          0.000       196          10.795593
#
# [548 rows x 11 columns]

# %%
plt.scatter(df_proj.fpts, df_proj.fpts_upside)

# %%
teams = 10
qb = 1
wr = 3
rb = 2
te = 1
flex = 1
bench = 5
dst = 1
k = 1
budget = 200

# %%
df_proj
# Out:
#                  player team position     fpts  fpts_ceil  fpts_floor  \
# 0    Patrick Mahomes II   KC       QB  384.136    420.674     338.588
# 1            Josh Allen  BUF       QB  380.346    420.004     342.844
# 2           Jalen Hurts  PHI       QB  376.470    449.660     305.198
# 3         Lamar Jackson  BAL       QB  351.434    399.730     275.120
# 4            Joe Burrow  CIN       QB  345.974    384.380     300.700
# ..                  ...  ...      ...      ...        ...         ...
# 540        Kirk Merritt   NO       WR    1.580     13.080       1.580
# 541        Kirk Merritt   NO       WR    1.580      1.580      13.080
# 542        Kirk Merritt   NO       WR    1.580      1.580       1.580
# 543    Laquon Treadwell  BAL       WR    0.950      0.950       0.950
# 545       Antoine Green  DET       WR    0.770      0.770       0.770
#
#      voltailty  fpts_upside  fpts_downside  pos_rank
# 0       82.086       36.538        -45.548         1
# 1       77.160       39.658        -37.502         2
# 2      144.462       73.190        -71.272         3
# 3      124.610       48.296        -76.314         4
# 4       83.680       38.406        -45.274         5
# ..         ...          ...            ...       ...
# 540     11.500       11.500          0.000       192
# 541    -11.500        0.000         11.500       193
# 542      0.000        0.000          0.000       194
# 543      0.000        0.000          0.000       195
# 545      0.000        0.000          0.000       196
#
# [548 rows x 10 columns]

# %%
df_proj[df_proj['position'].isin(['RB', 'WR'])].sort_values(by='fpts', ascending=False).iloc[90]
# Out:
# player           Odell Beckham Jr.
# team                           BAL
# position                        WR
# fpts                         96.35
# fpts_ceil                   126.43
# fpts_floor                   70.18
# voltailty                    56.25
# fpts_upside                  30.08
# fpts_downside               -26.17
# pos_rank                        49
# Name: 129, dtype: object

# %%
#Establish VBD
def assign_cutoff(row):
    if row['position'] == 'qb':
        return qb_cutoff
    elif row['position'] == 'rb':
        return rb_cutoff
    elif row['position'] == 'wr':
        return wr_cutoff
    elif row['position'] == 'te':
        return te_cutoff
    else:
        return None
    



#Change rank to pos rank
df_rb_proj = df_proj[(df_proj.position == 'RB') & (df_proj['pos_rank'] <= teams*(rb+flex))]
df_wr_proj = df_proj[(df_proj.position == 'wr') & (df_proj['pos_rank'] <= teams*(wr+flex))]
df_flex = df_rb_proj.append(df_wr_proj).sort_values(by=['fpts'], ascending=False)


flex_cutoff = df_flex.iloc[teams*(wr + rb + flex) - 1].fpts


qb_cutoff = df_proj[df_proj.position == 'qb'].iloc[teams*qb - 1].fpts
rb_cutoff = max(df_proj[df_proj.position == 'rb'].iloc[teams*(rb+flex) - 1].fpts,\
                min(df_proj[df_proj.position == 'rb'].iloc[teams*rb - 1].fpts, flex_cutoff))
wr_cutoff =  max(df_proj[df_proj.position == 'wr'].iloc[teams*(wr+flex) - 1].fpts,\
                min(df_proj[df_proj.position == 'wr'].iloc[teams*wr - 1].fpts, flex_cutoff))
te_cutoff = df_proj[df_proj.position == 'te'].iloc[teams*te - 1].fpts


    
df_proj['cutoff'] = df_proj.apply(assign_cutoff, axis=1)
df_proj['fpts_vbd'] = df_proj['fpts'] - df_proj.cutoff
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [53], in <module>
#      19 df_wr_proj = df_proj[(df_proj.position == 'wr') & (df_proj['pos_rank'] <= teams*(wr+flex))]
#      20 df_flex = df_rb_proj.append(df_wr_proj).sort_values(by=['fpts'], ascending=False)
# ---> 23 flex_cutoff = df_flex.iloc[teams*(wr + rb + flex) - 1].fpts
#      26 qb_cutoff = df_proj[df_proj.position == 'qb'].iloc[teams*qb - 1].fpts
#      27 rb_cutoff = max(df_proj[df_proj.position == 'rb'].iloc[teams*(rb+flex) - 1].fpts,\
#      28                 min(df_proj[df_proj.position == 'rb'].iloc[teams*rb - 1].fpts, flex_cutoff))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     928 axis = self.axis or 0
#     930 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1566, in _iLocIndexer._getitem_axis(self, key, axis)
#    1563     raise TypeError("Cannot index by location index with a non-integer key")
#    1565 # validate the location
# -> 1566 self._validate_integer(key, axis)
#    1568 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1500, in _iLocIndexer._validate_integer(self, key, axis)
#    1498 len_axis = len(self.obj._get_axis(axis))
#    1499 if key >= len_axis or key < -len_axis:
# -> 1500     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
df_flex
# Out:
# Empty DataFrame
# Columns: [player, team, position, fpts, fpts_ceil, fpts_floor, voltailty, fpts_upside, fpts_downside, pos_rank]
# Index: []

# %%
 df_rb_proj.append(df_wr_proj).sort_values(by=['fpts'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [player, team, position, fpts, fpts_ceil, fpts_floor, voltailty, fpts_upside, fpts_downside, pos_rank]
# Index: []

# %%
df_rb_proj
# Out:
#                  player team position    fpts  fpts_ceil  fpts_floor  \
# 24  Christian McCaffrey   SF       RB  233.42     269.46      193.26
# 26        Austin Ekeler  LAC       RB  223.75     264.82      169.90
# 28           Nick Chubb  CLE       RB  221.09     272.79      194.11
# 30        Derrick Henry  TEN       RB  220.41     260.66      183.35
# 33       Bijan Robinson  ATL       RB  213.88     260.88      176.20
# 34         Tony Pollard  DAL       RB  211.58     270.29      170.39
# 36          Josh Jacobs   LV       RB  209.80     249.82      183.93
# 37       Saquon Barkley  NYG       RB  207.68     259.00      177.96
# 39      Jonathan Taylor  IND       RB  203.02     250.70      168.99
# 45            Joe Mixon  CIN       RB  189.78     241.92      151.96
# 46          Aaron Jones   GB       RB  183.44     233.72      146.79
# 49         Najee Harris  PIT       RB  178.11     222.42      135.10
# 52   Travis Etienne Jr.  JAC       RB  175.11     208.91      142.43
# 53   Alexander Mattison  MIN       RB  173.57     203.75      135.00
# 54   Kenneth Walker III  SEA       RB  173.37     205.40      142.94
# 55  Rhamondre Stevenson   NE       RB  171.28     217.92      134.91
# 57         James Conner  ARI       RB  167.99     202.25      135.82
# 58        Dameon Pierce  HOU       RB  166.53     195.63      141.89
# 59         Jahmyr Gibbs  DET       RB  163.00     194.73      129.79
# 60          Breece Hall  NYJ       RB  160.76     198.07      129.54
# 61        Miles Sanders  CAR       RB  160.26     202.59      128.46
# 64         J.K. Dobbins  BAL       RB  156.70     193.76      133.83
# 65            Cam Akers  LAR       RB  156.00     197.50      119.58
# 66        Isiah Pacheco   KC       RB  154.76     189.69      121.48
# 68        Rachaad White   TB       RB  152.31     211.86       99.70
# 70     David Montgomery  DET       RB  148.42     183.09      109.60
# 71           James Cook  BUF       RB  148.23     166.56      121.30
# 80     Javonte Williams  DEN       RB  136.34     182.21      102.46
# 81         Alvin Kamara   NO       RB  135.94     164.59       97.89
# 86       Khalil Herbert  CHI       RB  132.74     158.00      103.63
#
#     voltailty  fpts_upside  fpts_downside  pos_rank
# 24      76.20        36.04         -40.16         1
# 26      94.92        41.07         -53.85         2
# 28      78.68        51.70         -26.98         3
# 30      77.31        40.25         -37.06         4
# 33      84.68        47.00         -37.68         5
# 34      99.90        58.71         -41.19         6
# 36      65.89        40.02         -25.87         7
# 37      81.04        51.32         -29.72         8
# 39      81.71        47.68         -34.03         9
# 45      89.96        52.14         -37.82        10
# 46      86.93        50.28         -36.65        11
# 49      87.32        44.31         -43.01        12
# 52      66.48        33.80         -32.68        13
# 53      68.75        30.18         -38.57        14
# 54      62.46        32.03         -30.43        15
# 55      83.01        46.64         -36.37        16
# 57      66.43        34.26         -32.17        17
# 58      53.74        29.10         -24.64        18
# 59      64.94        31.73         -33.21        19
# 60      68.53        37.31         -31.22        20
# 61      74.13        42.33         -31.80        21
# 64      59.93        37.06         -22.87        22
# 65      77.92        41.50         -36.42        23
# 66      68.21        34.93         -33.28        24
# 68     112.16        59.55         -52.61        25
# 70      73.49        34.67         -38.82        26
# 71      45.26        18.33         -26.93        27
# 80      79.75        45.87         -33.88        28
# 81      66.70        28.65         -38.05        29
# 86      54.37        25.26         -29.11        30
